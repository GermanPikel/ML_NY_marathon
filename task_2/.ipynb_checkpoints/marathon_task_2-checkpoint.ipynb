# %%
import pandas as pd

# %%
dishes = pd.read_csv('dishes.csv')
users = pd.read_csv('users.csv')
df = pd.read_csv('train_holodilnik.csv')
test_df = pd.read_csv('test_holodilnik.csv')

# %%
dishes
# Out:
#      dish_id               dish_name   category  calories  spicy  \
# 0          1                  Оливье      salad       480      0
# 1          2                Винегрет      salad       304      0
# 2          3          Салат «Мимоза»      salad       267      0
# 3          4         Греческий салат      salad       389      0
# 4          5                  Цезарь      salad       269      0
# ..       ...                     ...        ...       ...    ...
# 195      196                   Блины  breakfast       571      0
# 196      197       Сырники (завтрак)  breakfast       471      0
# 197      198            Авокадо-тост  breakfast       245      0
# 198      199  Овсянка (классический)  breakfast       605      0
# 199      200      Гранола (домашний)  breakfast       494      0
#
#      allergen_tags                                               tags
# 0    egg|mayo|peas                            fiber|savory|vegetarian
# ...

# %%
users
# Out:
#        user_id            allergies  \
# 0            1  chocolate|mayo|peas
# 1            2                  NaN
# 2            3                 mayo
# 3            4                  NaN
# 4            5                  NaN
# ...        ...                  ...
# 14995    14996          fish|gluten
# 14996    14997            dairy|egg
# 14997    14998                 peas
# 14998    14999                  NaN
# 14999    15000                 nuts
#
#                                               liked_tags  \
# 0      bread|chicken|fried|juice|pasta|seafood_tag|tu...
# 1                         coffee|compote|fried|tea|vegan
# 2      crispy|meat|pickled|savory|seafood_tag|soda|sweet
# 3                   coffee|fish_tag|meat|rice|smoky|soda
# 4            bread|coffee|fiber|fried|high_protein|smoky
# ...                                                  ...
# 14995  fiber|fresh|juice|meat|pasta|pork|seafood_tag|...
# 14996                 boiled|fish_tag|meat|potato|savory
# ...

# %%
df
# Out:
#         event_id  user_id  day   meal_slot  hangover_level  guests_count  \
# 0              1     4677    9       lunch               1             0
# 1              2     1179   14      dinner               0             2
# 2              3     9322    4      dinner               2             2
# 3              4     8418   10   breakfast               3             2
# 4              5     3665    7       lunch               3             2
# ...          ...      ...  ...         ...             ...           ...
# 299995    299996     3180    5       lunch               1             1
# 299996    299997     2501    3   breakfast               3             1
# 299997    299998    14126    1       lunch               3             5
# 299998    299999    10860    8  late_snack               1             0
# 299999    300000    12353   13      dinner               0             1
#
#         diet_mode  fridge_load_pct  cand_01  cand_02  ...  cand_12  cand_13  \
# ...
